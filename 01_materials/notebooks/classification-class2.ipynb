# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('./dataset/wdbc.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis']=df['diagnosis'].replace({'M':'Malign','B':"Beningn"})

# %%
df['diagnosis'].replace('B','Benign')
# Out:
# 0       Malign
# 1       Malign
# 2       Malign
# 3       Malign
# 4       Malign
#         ...
# 564     Malign
# 565     Malign
# 566     Malign
# 567     Malign
# 568    Beningn
# Name: diagnosis, Length: 569, dtype: object

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424    Malign        21.56         22.39          142.00     1479.0
# 565  926682    Malign        20.13         28.25          131.20     1261.0
# 566  926954    Malign        16.60         28.08          108.30      858.1
# 567  927241    Malign        20.60         29.33          140.10     1265.0
# 568   92751   Beningn         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424    Malign        21.56         22.39          142.00     1479.0
# 565  926682    Malign        20.13         28.25          131.20     1261.0
# 566  926954    Malign        16.60         28.08          108.30      858.1
# 567  927241    Malign        20.60         29.33          140.10     1265.0
# 568   92751   Beningn         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df_stand = df.copy()
df_stand.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_stand.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302    Malign        17.99         10.38          122.80     1001.0
# 1    842517    Malign        20.57         17.77          132.90     1326.0
# 2  84300903    Malign        19.69         21.25          130.00     1203.0
# 3  84348301    Malign        11.42         20.38           77.58      386.1
# 4  84358402    Malign        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
columns_exclude = ['id','dianosis']
columns_to_scale = df_stand.columns.difference(columns_exclude)

# %%
df_stand[columns_to_scale]
# Out:
#      area_mean  area_se  area_worst  compactness_mean  compactness_se  \
# 0       1001.0   153.40      2019.0           0.27760         0.04904
# 1       1326.0    74.08      1956.0           0.07864         0.01308
# 2       1203.0    94.03      1709.0           0.15990         0.04006
# 3        386.1    27.23       567.7           0.28390         0.07458
# 4       1297.0    94.44      1575.0           0.13280         0.02461
# ..         ...      ...         ...               ...             ...
# 564     1479.0   158.70      2027.0           0.11590         0.02891
# 565     1261.0    99.04      1731.0           0.10340         0.02423
# 566      858.1    48.55      1124.0           0.10230         0.03731
# 567     1265.0    86.22      1821.0           0.27700         0.06158
# 568      181.0    19.15       268.6           0.04362         0.00466
#
#      compactness_worst  concave points_mean  concave points_se  \
# ...

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(df_stand[columns_to_scale])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21960\2890406481.py in ?()
# ----> 1 scaler.fit_transform(df_stand[columns_to_scale])
#
# c:\Users\nages\miniconda3\envs\dsi_participant\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# c:\Users\nages\miniconda3\envs\dsi_participant\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
# ...

# %%
np.random.seed(42)

# %%
df_train,df_test = train_test_split(df_stand,train_size=0.8,shuffle=True,stratify=df_stand['diagnosis'])

# %%
model = KNeighborsClassifier(n_neighbors=5)

# %%
X = df_stand[['concavity_mean','perimeter_mean']]
y = df_stand['diagnosis']

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
df_test['prediction'] = model.predict(df_test[['perimeter_mean','concavity_mean']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df_test['prediction'] = model.predict(df_test[['perimeter_mean','concavity_mean']])
#
# File c:\Users\nages\miniconda3\envs\dsi_participant\lib\site-packages\sklearn\neighbors\_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# ...

# %%
model.score(df_test[['perimeter_mean','concavity_mean']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 model.score(df_test[['perimeter_mean','concavity_mean']])
#
# TypeError: score() missing 1 required positional argument: 'y'

# %%
precision_score(y_true=df_test['diagnosis'],y_pred=df_test['predicted'],pos_label='Malignant')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 precision_score(y_true=df_test['diagnosis'],y_pred=df_test['predicted'],pos_label='Malignant')
#
# NameError: name 'precision_score' is not defined
